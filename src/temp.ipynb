# %%
import json

with open("/data/taewon/project/CoR-ACL25/aica-report/sumfeed_cot.jsonl") as f:
    data = [json.loads(line) for line in f]

from datasets import Dataset

path = "hamzzi/refeed-llama3-C4-w-permutation-4K"

dataset = Dataset.from_list(data)
